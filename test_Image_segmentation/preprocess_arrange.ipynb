# %%
#!pip install nibabel tqdm scikit-image

# %%
import os
import sys
import random
import math
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image

from tqdm import tqdm
from skimage.metrics import peak_signal_noise_ratio, structural_similarity
from skimage.io import imread
from skimage.transform import pyramid_reduce, resize
from scipy.ndimage import zoom

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Activation, Conv2D, Flatten, Dense, MaxPooling2D, Dropout, Add, LeakyReLU, UpSampling2D, Conv2DTranspose, Concatenate, BatchNormalization
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import SGD

import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
from torch.autograd import Variable


from tensorflow.python.client import device_lib

# %%
#GPU 확인
print(tf.config.list_physical_devices('GPU'))
print(device_lib.list_local_devices())
tf.test.is_gpu_available()
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16914406814880792467
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 2914163099
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 9342421376805286081
# physical_device_desc: "device: 0, name: GeForce GTX 1050, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]
# WARNING:tensorflow:From <ipython-input-2-5e52d5af4050>:4: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
def preprocess(img_name):
    img_path = path

# %%
def img_resize(img) :
    image = resize(image, output_shape=(256, 256, 1), preserve_range=True)
    
    return img

# %%
#데이터 셋 가져오기
def get_mask_data():

    x_train_path = "dataset/Image_Segmentation/x_train.npy"
    x_val_path = "dataset/Image_Segmentation/x_val.npy" 
    y_train_path = "dataset/Image_Segmentation/y_train2.npy"
    y_val_path = "dataset/Image_Segmentation/y_val2.npy"
    
    x_train = np.load(x_train_path)
    x_val = np.load(x_val_path)
    y_train = np.load(y_train_path)
    y_val = np.load(y_val_path)

    print(x_train.shape, y_train.shape)
    print(x_val.shape, y_val.shape)
    
        
    return x_train, y_train, x_val, y_val

# %%
print(y_train.shape, y_val.shape)
print(y_train.dtype)
y_train2 = np.zeros((2675, 256, 256, 2), dtype=np.uint8)
y_val2 = np.zeros((298, 256, 256, 2), dtype=np.uint8)
y_train2[..., 0] = y_train[..., 0]
y_train2[..., 1] = 1 - y_train[..., 0]
y_val2[..., 0] = y_val[..., 0]
y_val2[..., 1] = 1-y_val[..., 0]
# y_train2 = np.zeros(2675)
# Out:
# (2675, 256, 256, 1) (298, 256, 256, 1)
# float32

# %%
# plt.imshow(y_train[100, :, :, 1])
print(y_train2.max(), y_train2.min())
# Out:
# 1.0 0.0

# %%
y_train2 = np.asarray(y_train2).astype('float32').reshape((-1,1))

# %%
y_val2 = np.asarray(y_val2).astype('float32').reshape((-1,1))

# %%
np.save("dataset/Image_Segmentation/y_train2.npy",y_train2 )
np.save("dataset/Image_Segmentation/y_val2.npy",y_val2 )

# %%
# CNN 인 VGG16 U-net
def VGG16_Unet(x_train, y_train, x_val, y_val) :
  
    inputs = Input(shape=(256, 256, 1))

    #down sampling 
    filters = 16       #feature map 수
    kernel_size = 3    # kernel size
    copy_layers = []   # Encoder에 있는 Activation map을 저장하는 리스트
    net = inputs
  
    #Encoder1
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = BatchNormalization() (net)
    copy_layers.append(net) #첫번째 Activation map 저장
    net = MaxPooling2D((2, 2), strides=(2, 2)) (net)
    filters = filters*2
    
    #Encoder2 
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = BatchNormalization() (net)
    copy_layers.append(net) #두번째 Activation map 저장
    net = MaxPooling2D((2, 2), strides=(2, 2)) (net)
    filters = filters*2
    
    #Encoder3
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = BatchNormalization() (net)
    copy_layers.append(net) #세번째 Activation map 저장
    net = MaxPooling2D((2, 2), strides=(2, 2)) (net)
    filters = filters*2
    
    #Encoder4
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = BatchNormalization() (net)
    copy_layers.append(net) #네번째 Activation map 저장
    net = MaxPooling2D((2, 2), strides=(2, 2)) (net)
    
    #Encoder5
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = BatchNormalization() (net)
    copy_layers.append(net) #다섯번째 Activation map 저장
    net = MaxPooling2D((2, 2), strides=(2, 2)) (net)
    
    #128
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = BatchNormalization() (net)
    
    
    #Decoder : upsampling
    j = len(copy_layers) - 1
    net = Conv2DTranspose(filters, 2, strides=(2, 2), padding='same') (net)
    net = Concatenate(axis=3)([net, copy_layers[j]]) #다섯번째 Activation map 
    
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = BatchNormalization() (net)
    j = j -1 

    net = Conv2DTranspose(filters, 2, strides=(2, 2), padding='same') (net)
    net = Concatenate(axis=3)([net, copy_layers[j]]) #네번째 Activation map
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = BatchNormalization() (net)

    filters = filters/2
    j = j -1 
    
    net = Conv2DTranspose(filters, 2, strides=(2, 2), padding='same') (net)
    net = Concatenate(axis=3)([net, copy_layers[j]]) #세번째 Activation map
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = BatchNormalization() (net)

    filters = filters/2
    j = j -1 
    
    net = Conv2DTranspose(filters, 2, strides=(2, 2), padding='same') (net)
    net = Concatenate(axis=3)([net, copy_layers[j]]) #두번째 Activation map
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = BatchNormalization() (net)
    
    filters = filters/2
    j = j -1 
    
    net = Conv2DTranspose(filters, 2, strides=(2, 2), padding='same') (net)
    net = Concatenate(axis=3)([net, copy_layers[j]]) #첫번째 Activation map
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = Conv2D(filters, kernel_size, activation='relu', padding='same') (net)
    net = BatchNormalization() (net)
    
    outputs = Conv2D(2, 1, activation='sigmoid') (net)




    model = Model(inputs=inputs, outputs=outputs)

    model.compile(optimizer='rmsprop', loss='binary_crossentropy', 
                  metrics=['acc',tf.keras.metrics.MeanIoU(num_classes=2)])

    model.summary()
    
    
    

    return model

# %%
def training(model,x_train, y_train, x_val, y_val) :
    history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=100, batch_size=16, 
                      callbacks=[ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, verbose=1, mode='auto', min_lr=1e-05)])
    fig, ax = plt.subplots(3, 2, figsize=(10, 7))
    plt.subplots_adjust(left=0.125,bottom=0.1, right=0.9, top=1.5, wspace=0.2, hspace=0.35)

    
    ax[0, 0].set_title('loss')
    ax[0, 0].plot(history.history['loss'], 'r')
    ax[0, 1].set_title('acc')
    ax[0, 1].plot(history.history['acc'], 'b')

    ax[1, 0].set_title('val_loss')
    ax[1, 0].plot(history.history['val_loss'], 'r--')
    ax[1, 1].set_title('val_acc')
    ax[1, 1].plot(history.history['val_acc'], 'b--')
    
    ax[2,0].set_title('MeanIoU')
    ax[2,0].plot(history.history['mean_io_u'], 'r')
    ax[2,1].set_title('val_MeanIoU')
    ax[2,1].plot(history.history['val_mean_io_u'], 'r')
    

    preds = model.predict(x_val)
    fig, ax = plt.subplots(40, 4, figsize=(10, 100))
    
    temp = np.empty((256, 256, 1), dtype=np.float32)

    for i in range(40):
        ax[i, 0].imshow(x_val[i].squeeze(), cmap='gray')
        ax[i, 0].title.set_text(str(i))
        ax[i, 1].imshow(y_val[i].squeeze(), cmap='gray')
        ax[i, 2].imshow(preds[i].squeeze(), cmap='gray')
        temp = x_val[i]
        pred_sum = preds[i][preds[i] > 0]
        pred_mean = np.mean(pred_sum)
        if(np.min(temp) >= 0) :
            temp[preds[i] < pred_mean] = 0
        else :
            temp[preds[i] < pred_mean] = -2048
        ax[i, 3].imshow(temp.squeeze(), cmap='gray')

# %%
x_train, y_train, x_val, y_val = get_mask_data()
# model = VGG16_Unet(x_train, y_train2, x_val, y_val2)
# history = training(model,x_train, y_train2, x_val, y_val2)
# Out:
# (2675, 256, 256, 1) (2675, 256, 256, 1)
# (298, 256, 256, 1) (298, 256, 256, 1)

# %%
model = VGG16_Unet(x_train, y_train2, x_val, y_val2)
history = training(model,x_train, y_train2, x_val, y_val2)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 16) 160         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 2320        conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 32) 4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 32) 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 64)   36928       conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 64)   36928       conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 128)  147584      conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 128)  147584      conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 128)  147584      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 128)    147584      max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 128)    512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 128)  65664       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 256)  0           conv2d_transpose[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 128)  295040      concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 128)  65664       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 256)  0           conv2d_transpose_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 128)  147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 128)  147584      conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 128)  512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 64)   32832       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_2[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 64)   36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 64)   36928       conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 32) 8224        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_3[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 32) 9248        conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 128, 128, 32) 9248        conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 128, 128, 32) 128         conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 256, 256, 16) 2064        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 32) 0           conv2d_transpose_4[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 256, 256, 16) 4624        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 256, 256, 16) 2320        conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 256, 256, 16) 2320        conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 256, 256, 16) 64          conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 256, 256, 2)  34          batch_normalization_10[0][0]
# ==================================================================================================
# Total params: 2,620,306
# Trainable params: 2,618,578
# Non-trainable params: 1,728
# __________________________________________________________________________________________________
# Epoch 1/100
# 168/168 [==============================] - 98s 495ms/step - loss: 0.2535 - acc: 0.9447 - mean_io_u: 0.2505 - val_loss: 1.2762 - val_acc: 0.8436 - val_mean_io_u: 0.2637
# Epoch 2/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0532 - acc: 0.9887 - mean_io_u: 0.2646 - val_loss: 0.3071 - val_acc: 0.9356 - val_mean_io_u: 0.2513
# Epoch 3/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0271 - acc: 0.9919 - mean_io_u: 0.2833 - val_loss: 10.7795 - val_acc: 0.7343 - val_mean_io_u: 0.2771
# Epoch 4/100
# 168/168 [==============================] - 78s 465ms/step - loss: 0.0173 - acc: 0.9942 - mean_io_u: 0.2871 - val_loss: 0.1268 - val_acc: 0.9734 - val_mean_io_u: 0.3127
# Epoch 5/100
# 168/168 [==============================] - 78s 466ms/step - loss: 0.0158 - acc: 0.9944 - mean_io_u: 0.2875 - val_loss: 0.2665 - val_acc: 0.9501 - val_mean_io_u: 0.2803
# Epoch 6/100
# 168/168 [==============================] - 78s 465ms/step - loss: 0.0143 - acc: 0.9951 - mean_io_u: 0.2807 - val_loss: 0.4283 - val_acc: 0.9204 - val_mean_io_u: 0.2504
# Epoch 7/100
# 168/168 [==============================] - 78s 465ms/step - loss: 0.0129 - acc: 0.9954 - mean_io_u: 0.2793 - val_loss: 0.0152 - val_acc: 0.9945 - val_mean_io_u: 0.2701
# Epoch 8/100
# 168/168 [==============================] - 78s 465ms/step - loss: 0.0127 - acc: 0.9953 - mean_io_u: 0.2635 - val_loss: 0.0406 - val_acc: 0.9874 - val_mean_io_u: 0.2709
# Epoch 9/100
# 168/168 [==============================] - 77s 459ms/step - loss: 0.0108 - acc: 0.9960 - mean_io_u: 0.2634 - val_loss: 0.0126 - val_acc: 0.9959 - val_mean_io_u: 0.2917
# Epoch 10/100
# 168/168 [==============================] - 77s 458ms/step - loss: 0.0109 - acc: 0.9960 - mean_io_u: 0.2589 - val_loss: 0.0089 - val_acc: 0.9965 - val_mean_io_u: 0.2507
# Epoch 11/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0101 - acc: 0.9962 - mean_io_u: 0.2585 - val_loss: 0.1054 - val_acc: 0.9827 - val_mean_io_u: 0.2590
# Epoch 12/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0092 - acc: 0.9964 - mean_io_u: 0.2575 - val_loss: 0.0139 - val_acc: 0.9953 - val_mean_io_u: 0.2799
# Epoch 13/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0091 - acc: 0.9965 - mean_io_u: 0.2546 - val_loss: 0.0163 - val_acc: 0.9943 - val_mean_io_u: 0.2518
# Epoch 14/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0088 - acc: 0.9966 - mean_io_u: 0.2537 - val_loss: 0.0121 - val_acc: 0.9958 - val_mean_io_u: 0.2605
# Epoch 15/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0088 - acc: 0.9966 - mean_io_u: 0.2544 - val_loss: 0.0169 - val_acc: 0.9947 - val_mean_io_u: 0.2545
# Epoch 16/100
# 168/168 [==============================] - 78s 462ms/step - loss: 0.0088 - acc: 0.9966 - mean_io_u: 0.2540 - val_loss: 0.0106 - val_acc: 0.9959 - val_mean_io_u: 0.2522
# Epoch 17/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0085 - acc: 0.9967 - mean_io_u: 0.2540 - val_loss: 0.0093 - val_acc: 0.9965 - val_mean_io_u: 0.2663
# Epoch 18/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0087 - acc: 0.9966 - mean_io_u: 0.2537 - val_loss: 0.0087 - val_acc: 0.9966 - val_mean_io_u: 0.2576
# Epoch 19/100
# 168/168 [==============================] - 79s 468ms/step - loss: 0.0083 - acc: 0.9967 - mean_io_u: 0.2534 - val_loss: 0.0913 - val_acc: 0.9798 - val_mean_io_u: 0.2738
# Epoch 20/100
# 168/168 [==============================] - 79s 469ms/step - loss: 0.0080 - acc: 0.9968 - mean_io_u: 0.2552 - val_loss: 0.0138 - val_acc: 0.9946 - val_mean_io_u: 0.3026
# Epoch 21/100
# 168/168 [==============================] - 78s 465ms/step - loss: 0.0079 - acc: 0.9969 - mean_io_u: 0.2546 - val_loss: 0.0080 - val_acc: 0.9968 - val_mean_io_u: 0.2569
# Epoch 22/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0079 - acc: 0.9968 - mean_io_u: 0.2544 - val_loss: 0.0306 - val_acc: 0.9892 - val_mean_io_u: 0.2614
# Epoch 23/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0076 - acc: 0.9969 - mean_io_u: 0.2564 - val_loss: 0.0092 - val_acc: 0.9964 - val_mean_io_u: 0.2687
# Epoch 24/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0076 - acc: 0.9969 - mean_io_u: 0.2547 - val_loss: 0.0087 - val_acc: 0.9966 - val_mean_io_u: 0.2561
# Epoch 25/100
# 168/168 [==============================] - 77s 458ms/step - loss: 0.0077 - acc: 0.9969 - mean_io_u: 0.2555 - val_loss: 0.0077 - val_acc: 0.9969 - val_mean_io_u: 0.2708
# Epoch 26/100
# 168/168 [==============================] - 78s 462ms/step - loss: 0.0076 - acc: 0.9969 - mean_io_u: 0.2556 - val_loss: 0.0091 - val_acc: 0.9966 - val_mean_io_u: 0.2943
# Epoch 27/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0074 - acc: 0.9970 - mean_io_u: 0.2580 - val_loss: 0.0118 - val_acc: 0.9956 - val_mean_io_u: 0.2556
# Epoch 28/100
# 168/168 [==============================] - 79s 468ms/step - loss: 0.0074 - acc: 0.9970 - mean_io_u: 0.2568 - val_loss: 0.0079 - val_acc: 0.9968 - val_mean_io_u: 0.2609
# Epoch 29/100
# 168/168 [==============================] - 79s 468ms/step - loss: 0.0073 - acc: 0.9970 - mean_io_u: 0.2567 - val_loss: 0.0076 - val_acc: 0.9970 - val_mean_io_u: 0.2811
# Epoch 30/100
# 168/168 [==============================] - 78s 467ms/step - loss: 0.0073 - acc: 0.9970 - mean_io_u: 0.2575 - val_loss: 0.0077 - val_acc: 0.9969 - val_mean_io_u: 0.2732
# Epoch 31/100
# 168/168 [==============================] - 78s 462ms/step - loss: 0.0072 - acc: 0.9971 - mean_io_u: 0.2574 - val_loss: 0.0088 - val_acc: 0.9967 - val_mean_io_u: 0.2812
# Epoch 32/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0072 - acc: 0.9971 - mean_io_u: 0.2580 - val_loss: 0.0073 - val_acc: 0.9971 - val_mean_io_u: 0.2629
# Epoch 33/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0071 - acc: 0.9971 - mean_io_u: 0.2580 - val_loss: 0.0391 - val_acc: 0.9913 - val_mean_io_u: 0.2710
# Epoch 34/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0070 - acc: 0.9971 - mean_io_u: 0.2594 - val_loss: 0.0086 - val_acc: 0.9968 - val_mean_io_u: 0.2953
# Epoch 35/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0069 - acc: 0.9972 - mean_io_u: 0.2601 - val_loss: 0.0134 - val_acc: 0.9959 - val_mean_io_u: 0.2585
# Epoch 36/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0068 - acc: 0.9972 - mean_io_u: 0.2614 - val_loss: 0.0072 - val_acc: 0.9971 - val_mean_io_u: 0.2593
# Epoch 37/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0069 - acc: 0.9972 - mean_io_u: 0.2621 - val_loss: 0.0073 - val_acc: 0.9971 - val_mean_io_u: 0.2743
# Epoch 38/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0068 - acc: 0.9972 - mean_io_u: 0.2606 - val_loss: 0.0102 - val_acc: 0.9964 - val_mean_io_u: 0.2798
# Epoch 39/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0068 - acc: 0.9972 - mean_io_u: 0.2613 - val_loss: 0.0111 - val_acc: 0.9960 - val_mean_io_u: 0.2767
# Epoch 40/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0067 - acc: 0.9972 - mean_io_u: 0.2625 - val_loss: 0.0084 - val_acc: 0.9967 - val_mean_io_u: 0.2630
# Epoch 41/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0067 - acc: 0.9973 - mean_io_u: 0.2625 - val_loss: 0.0103 - val_acc: 0.9961 - val_mean_io_u: 0.2954
# Epoch 42/100
# 168/168 [==============================] - 78s 465ms/step - loss: 0.0066 - acc: 0.9973 - mean_io_u: 0.2634 - val_loss: 0.0081 - val_acc: 0.9968 - val_mean_io_u: 0.2679
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 43/100
# 168/168 [==============================] - 78s 465ms/step - loss: 0.0061 - acc: 0.9975 - mean_io_u: 0.2635 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2662
# Epoch 44/100
# 168/168 [==============================] - 78s 465ms/step - loss: 0.0059 - acc: 0.9975 - mean_io_u: 0.2654 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2629
# Epoch 45/100
# 168/168 [==============================] - 78s 465ms/step - loss: 0.0059 - acc: 0.9976 - mean_io_u: 0.2679 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2615
# Epoch 46/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0059 - acc: 0.9976 - mean_io_u: 0.2675 - val_loss: 0.0066 - val_acc: 0.9973 - val_mean_io_u: 0.2661
# Epoch 47/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0058 - acc: 0.9976 - mean_io_u: 0.2686 - val_loss: 0.0066 - val_acc: 0.9973 - val_mean_io_u: 0.2679
# Epoch 48/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0058 - acc: 0.9976 - mean_io_u: 0.2711 - val_loss: 0.0068 - val_acc: 0.9973 - val_mean_io_u: 0.2683
# Epoch 49/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0058 - acc: 0.9976 - mean_io_u: 0.2717 - val_loss: 0.0066 - val_acc: 0.9973 - val_mean_io_u: 0.2692
# Epoch 50/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0058 - acc: 0.9976 - mean_io_u: 0.2724 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2745
# Epoch 51/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0057 - acc: 0.9976 - mean_io_u: 0.2727 - val_loss: 0.0069 - val_acc: 0.9972 - val_mean_io_u: 0.2763
# Epoch 52/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0057 - acc: 0.9976 - mean_io_u: 0.2729 - val_loss: 0.0068 - val_acc: 0.9973 - val_mean_io_u: 0.2700
# Epoch 53/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0056 - acc: 0.9976 - mean_io_u: 0.2746 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2727
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 54/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0056 - acc: 0.9977 - mean_io_u: 0.2739 - val_loss: 0.0066 - val_acc: 0.9973 - val_mean_io_u: 0.2714
# Epoch 55/100
# 168/168 [==============================] - 78s 465ms/step - loss: 0.0055 - acc: 0.9977 - mean_io_u: 0.2749 - val_loss: 0.0066 - val_acc: 0.9973 - val_mean_io_u: 0.2746
# Epoch 56/100
# 168/168 [==============================] - 77s 459ms/step - loss: 0.0055 - acc: 0.9977 - mean_io_u: 0.2757 - val_loss: 0.0066 - val_acc: 0.9973 - val_mean_io_u: 0.2752
# Epoch 57/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0055 - acc: 0.9977 - mean_io_u: 0.2760 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2738
# Epoch 58/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0055 - acc: 0.9977 - mean_io_u: 0.2764 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2758
# Epoch 59/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0055 - acc: 0.9977 - mean_io_u: 0.2768 - val_loss: 0.0066 - val_acc: 0.9973 - val_mean_io_u: 0.2765
# Epoch 60/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0055 - acc: 0.9977 - mean_io_u: 0.2771 - val_loss: 0.0066 - val_acc: 0.9973 - val_mean_io_u: 0.2772
# Epoch 61/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0055 - acc: 0.9977 - mean_io_u: 0.2772 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2772
# Epoch 62/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0055 - acc: 0.9977 - mean_io_u: 0.2775 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2762
# Epoch 63/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0055 - acc: 0.9977 - mean_io_u: 0.2782 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2787
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 64/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0055 - acc: 0.9977 - mean_io_u: 0.2783 - val_loss: 0.0066 - val_acc: 0.9973 - val_mean_io_u: 0.2774
# Epoch 65/100
# 168/168 [==============================] - 78s 465ms/step - loss: 0.0055 - acc: 0.9977 - mean_io_u: 0.2785 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2778
# Epoch 66/100
# 168/168 [==============================] - 78s 465ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2784 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2779
# Epoch 67/100
# 168/168 [==============================] - 78s 467ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2789 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2785
# Epoch 68/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2791 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2789
# Epoch 69/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2796 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2789
# Epoch 70/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2793 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2792
# Epoch 71/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2796 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2795
# Epoch 72/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0055 - acc: 0.9977 - mean_io_u: 0.2798 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2807
# Epoch 73/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2798 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2795
# Epoch 74/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0055 - acc: 0.9977 - mean_io_u: 0.2799 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2795
# Epoch 75/100
# 168/168 [==============================] - 77s 459ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2799 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2795
# Epoch 76/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2800 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2794
# Epoch 77/100
# 168/168 [==============================] - 78s 462ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2803 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2795
# Epoch 78/100
# 168/168 [==============================] - 78s 462ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2806 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2801
# Epoch 79/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2805 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2809
# Epoch 80/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2808 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2809
# Epoch 81/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2807 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2807
# Epoch 82/100
# 168/168 [==============================] - 78s 465ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2807 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2804
# Epoch 83/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2809 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2805
# Epoch 84/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2809 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2807
# Epoch 85/100
# 168/168 [==============================] - 78s 462ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2807 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2799
# Epoch 86/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2809 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2804
# Epoch 87/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2812 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2816
# Epoch 88/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2812 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2811
# Epoch 89/100
# 168/168 [==============================] - 78s 462ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2814 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2818
# Epoch 90/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2813 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2811
# Epoch 91/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2818 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2824
# Epoch 92/100
# 168/168 [==============================] - 77s 460ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2817 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2812
# Epoch 93/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2818 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2819
# Epoch 94/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2814 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2821
# Epoch 95/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2815 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2819
# Epoch 96/100
# 168/168 [==============================] - 79s 468ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2817 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2817
# Epoch 97/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2820 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2813
# Epoch 98/100
# 168/168 [==============================] - 78s 463ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2818 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2824
# Epoch 99/100
# 168/168 [==============================] - 78s 464ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2820 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2818
# Epoch 100/100
# 168/168 [==============================] - 77s 458ms/step - loss: 0.0054 - acc: 0.9977 - mean_io_u: 0.2822 - val_loss: 0.0067 - val_acc: 0.9973 - val_mean_io_u: 0.2825
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-8ccac8d9e28a> in <module>
#       1 model = VGG16_Unet(x_train, y_train2, x_val, y_val2)
# ----> 2 history = training(model,x_train, y_train2, x_val, y_val2)
#
# <ipython-input-9-212d89e98c80> in training(model, x_train, y_train, x_val, y_val)
#      30         ax[i, 0].imshow(x_val[i].squeeze(), cmap='gray')
#      31         ax[i, 0].title.set_text(str(i))
# ---> 32         ax[i, 1].imshow(y_val[i].squeeze(), cmap='gray')
#      33         ax[i, 2].imshow(preds[i].squeeze(), cmap='gray')
#      34         temp = x_val_0[i]
#
# c:\users\bch96\appdata\local\programs\python\python38\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\users\bch96\appdata\local\programs\python\python38\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# c:\users\bch96\appdata\local\programs\python\python38\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     709         if not (self._A.ndim == 2
#     710                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 711             raise TypeError("Invalid shape {} for image data"
#     712                             .format(self._A.shape))
#     713
#
# TypeError: Invalid shape (256, 256, 2) for image data

# %%
preds = model.predict(x_val)
fig, ax = plt.subplots(40, 4, figsize=(10, 100))
    
temp = np.empty((256, 256, 1), dtype=np.float32)

for i in range(40):
    ax[i, 0].imshow(x_val[i].squeeze(), cmap='gray')
    ax[i, 0].title.set_text(str(i))
    
    y_val_0 = y_val[...,0]
    ax[i, 1].imshow(y_val_0[i].squeeze(), cmap='gray')
    
    predict_0 = preds[...,0]
    ax[i, 2].imshow(predict_0[i].squeeze(), cmap='gray')
    
    temp = x_val[i]
    pred_sum = predict_0[i][predict_0[i] > 0]
    pred_mean = np.mean(predict_0)
    if(np.min(temp) >= 0) :
        temp[predict_0[i] < 0.5] = 0
    else :
        temp[predict_0[i] < 0.5] = -2048
    ax[i, 3].imshow(temp.squeeze(), cmap='gray')

# %%
x_train_again, y_train_again, x_val_again, y_val_again = get_mask_data()

pre = model.predict(x_val_again)

def plot_roc_curve(fper, tper):
    plt.plot(fper, tper, color='red', label='ROC')
    plt.plot([0, 1], [0, 1], color='green', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic Curve')
    plt.legend()
    plt.show()
# Out:
# (2675, 256, 256, 1) (2675, 256, 256, 2)
# (298, 256, 256, 1) (298, 256, 256, 2)

# %%
print(pre.shape, y_val_again.shape)
# Out:
# (298, 256, 256, 2) (298, 256, 256, 2)

# %%
ground_truth_labels = y_val_again.ravel() # we want to make them into vectors
score_value = pre.ravel()

# %%
fpr, tpr, _ = roc_curve(ground_truth_labels,score_value)
roc_auc = auc(fpr,tpr)

# %%
fig, ax = plt.subplots(1,1)
ax.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver operating characteristic example')
ax.legend(loc="lower right")

# %%
def get_predict_part(original ,predict) :
    copy_original = original.copy()
    
    for k, pred in enumerate(predict):
        if(np.min(copy_original[k]) >= 0) :
            copy_original[k][pred < 0.5] = 0
        else :
            copy_original[k][pred < 0.5] = -2048
            
    return copy_original

# %%
all_data_path= "transe"
original_data_path = "transe/data"
answer_data_path = "transe/transe"

data_set_folder_list = os.listdir(original_data_path)

for i, folder_name in enumerate(data_set_folder_list):
    address  = original_data_path + '/' + folder_name
    folder_video_set = os.listdir(address)
    for j, tar_name in enumerate(folder_video_set) :
        tar_address = address + '/' + tar_name
        raw_img = nib.load(tar_address)
        img_array = np.array(raw_img.get_fdata(), dtype=np.float32)
        images = img_array.T
        img_data = np.empty(( len(images), 256, 256, 1), dtype=np.float32)
        for i, image_array in enumerate(images) :
            img = resize(image_array, output_shape=(256, 256, 1), preserve_range=True)
            img_data[i] = img
        pres = model.predict(img_data)
        
        predict_lung = get_predict_part(img_data ,pres)
        
        
        
        save_address = answer_data_path + "/" + folder_name + "/" + tar_name
        np.save(save_address, predict_lung)

# %%
fff = 'transe/transe/CT-2/study_0939.nii.gz.npy'
sss=np.load(fff)

fig, ax = plt.subplots(54, 1, figsize=(10, 100))
    

for i in range(54):
    ax[i].imshow(sss[i].squeeze())

# %%
# def get_predict_part(original ,predict) :
#     copy_original = original.copy()
    
#     for k, pred in enumerate(predict):
#         pred_sum = pred[pred > 0]
#         pred_mean = np.mean(pred_sum)
#         if(np.min(copy_original[k]) >= 0) :
#             copy_original[k][pred < pred_mean] = 0
#         else :
#             copy_original[k][pred < pred_mean] = -2048
            
#     return copy_original

# %%
covid_path = "transe/COVID-19"
penumonia_path = "transe/non-COVID-19/CP"

covid_list = os.listdir(penumonia_path)
#penumonia_list = os.listdir(penumonia_path)
count = 0


for i, name in enumerate(covid_list) :
    address = penumonia_path + "/" + name
#     os.makedirs("transe/done_non-COVID-19/" + name)
    image_list = os.listdir(address)
    image_set = np.empty((len(image_list), 256, 256, 1), dtype = np.float32)
    for j, image_name in enumerate(image_list):
        image_path = os.path.join(address, image_name)
        img = Image.open(image_path)
        image_array = np.asarray(img)
        image = resize(image_array, output_shape=(256, 256, 1), preserve_range=True)
        image_set[j] = image
    predict = model.predict(image_set)
    
    for i, pred in enumerate(predict):
        pred_sum = pred[pred> 0]
        pred_mean = np.mean(pred_sum)
        if(np.min(image_set[i]) >= 0) :
            image_set[i][pred < pred_mean] = 0
        else :
            image_set[i][pred < pred_mean] = -2048

    
    predict_lung = get_predict_part(image_set ,predict)
    directory_path = "transe/done_non-COVID-19/" + name +"/"+ str(i)
#     fig, ax = plt.subplots(len(predict_lung), 2, figsize=(10, 100))
#     for i, lung in enumerate(predict_lung) :
#         ax[i,0].imshow(image_set[i].squeeze(), cmap='gray')
#         ax[i,1].imshow(lung.squeeze(), cmap='gray')
#     tem = input()
#     if(tem != 'y') : break
    np.save(directory_path, predict_lung)

# %%
covid_path = "transe/done_COVID-19"

covid_list = os.listdir(covid_path)
#penumonia_list = os.listdir(penumonia_path)
count = 0

address = "transe/done_COVID-19/" + covid_list[3]
image_list = os.listdir(address)

image_path = os.path.join(address, image_list[0])
img_set = np.load(image_path)

fig, ax = plt.subplots(len(img_set), 1, figsize=(10, 100))
plt.subplots_adjust(left=0.125,bottom=0.1, right=0.9, top=1.5, wspace=0.2, hspace=0.35)
print(address)
for i, lung in enumerate(img_set) :
    ax[i].title.set_text(str(i))
    ax[i].imshow(lung.squeeze(), cmap='gray')
